# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# import matplotlib.pyplot as plt

# %%
col_names = ["class","Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium",
         "Total phenols","Flavanoids","Nonflavanoid phenols","Proanthocyanins",
         "Color intensity","Hue","OD280/OD315 of diluted wines","Proline"]
len(col_names)
# Out:
# 14

# %%
df = pd.read_csv("../Data Analysis/Data/wine.data", sep =",", names = col_names)

# %%
df.head()
# Out:
#    class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %%
df["class"].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: class, dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %%
df.duplicated().value_counts()
# Out:
# False    178
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# saving as an excel file
df.to_excel("../Data Analysis/Data/wine.xlsx")

# %%
# rading second sheet
wine_data = pd.read_excel("../Data Analysis/Data/wine.xlsx", sheet_name = 1, index_col = 0)
wine_data.head()
# Out:
#    class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue
# 0             5.64  1.04
# 1             4.38  1.05
# 2             5.68  1.03
# 3             7.80  0.86
# 4             4.32  1.04

# %%
# alternatively
wine_data1 = pd.read_excel("../Data Analysis/Data/wine.xlsx", sheet_name = "Manupulated_data", index_col = 0)
wine_data1.head()
# Out:
#    class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue
# 0             5.64  1.04
# 1             4.38  1.05
# 2             5.68  1.03
# 3             7.80  0.86
# 4             4.32  1.04

# %%
# multiple excel sheets ~gives a dictionary
wine_data2 = pd.read_excel("../Data Analysis/Data/wine.xlsx", sheet_name = [0,1], index_col = 0)
wine_data2.keys()
# Out:
# dict_keys([0, 1])

# %%
# accessing data from the dict DataFrame above
# first sheet 
wine_data2[0].head()
# Out:
#    class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %%
# separating the sheets to different data frames
wine_data3 = wine_data2[0]
wine_data3.head()
# Out:
#    class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %%
# incase the data is not in the same place with notebook; data path use the below
# ../

# %%
trial = pd.read_csv("../Data Analysis/Data/students_data.csv", index_col = 0)
trial.head()
# Out:
#                    names  admission number house balance  english  kiswahili  \
# 0    JERIEL NDEDA, OBURA           13259.0   NaN     NaN     81.0       39.0
# 1  MUKUHA TIMOTHY, KAMAU           13243.0   NaN     NaN     85.0       74.0
# 2             JOB, NGARA           13307.0   NaN     NaN     54.0       49.0
# 3     CHEGE DAVID, KAMAU           13258.0   NaN     NaN     71.0       97.0
# 4    RAMADHAN MUSA, TEPO           13363.0   NaN     NaN     40.0       84.0
#
#    mathematics  science  sst/cre Creative Arts music
# 0         50.0     30.0     59.0           99%   80%
# 1         68.0     49.0     78.0           38%   86%
# 2         53.0     59.0     72.0           86%   62%
# 3         92.0     41.0     81.0           77%   80%
# 4         74.0     82.0     89.0           64%   46%

# %%
# load new data set~ header specifies the column name from dataset
sample_data = pd.read_excel("../Data Analysis/Data/Sample Data.xlsx", header = 4)
sample_data.head()
# Out:
#    Unnamed: 0  Day Month  Year      Code    No.  Day.1 Month.1  Year.1  \
# 0         NaN    3   Apr  2023      QRCR   E642      3     Apr    2023
# 1         NaN    3   Apr  2023      QRCR  E1411     31     Oct    2022
# 2         NaN    3   Apr  2023      QRCR   E649      3     Apr    2023
# 3         NaN    3   Apr  2023      QRCR   E638      3     Apr    2023
# 4         NaN    3   Apr  2023  QRCRMISC   E109      3     Apr    2023
#
#    Name of Court  ...   F  Org.  M.1  F.1 Org..1  (Y/N)  P \n(Enter No.)  \
# 0            NaN  ... NaN   1.0  1.0  NaN    NaN     No              NaN
# 1            NaN  ... NaN   1.0  1.0  NaN    NaN     No              NaN
# 2            NaN  ... NaN   1.0  1.0  NaN    NaN     No              NaN
# 3            NaN  ... NaN   1.0  1.0  NaN    NaN     No              NaN
# 4            NaN  ... NaN   1.0  NaN  2.0    NaN     No              NaN
#
#    D\n(Enter No.)  (Enter No.)  (Free text)
# 0             NaN          1.0          NaN
# ...

# %%
# list to sets
my_list = [1,4,4,8,9,5,5,5,5,4]
print(my_list)
# Out:
# [1, 4, 4, 8, 9, 5, 5, 5, 5, 4]

# %%
# sets
set(my_list)
# Out:
# {1, 4, 5, 8, 9}

# %%
z = pd.DataFrame(my_list)
z.head()
# Out:
#    0
# 0  1
# 1  4
# 2  4
# 3  8
# 4  9

# %%
# using set to check duplicates
set(z.duplicated())
# Out:
# {False, True}

# %%
z.duplicated().value_counts()
# Out:
# True     5
# False    5
# dtype: int64
